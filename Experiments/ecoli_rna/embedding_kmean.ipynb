# %%
import numpy as np
datapath = "../../Preprocessing/Encoded_Data/ecoli_rna_embeddings.npz"
data = np.load(datapath)
embeddings = data["embeddings"]
labels = data["labels"]

# %%
mid_layer  = embeddings[:, 0, :]
last_layer = embeddings[:, 1, :]
pooled = embeddings.mean(axis=1)

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import v_measure_score

kmeans = MiniBatchKMeans(n_clusters=3, random_state=42)
pred_labels = kmeans.fit_predict(mid_layer)

v_measure = v_measure_score(labels, pred_labels)
print(f"V-Measure Score: {v_measure:.4f}")
print(f"Number of clusters found: {len(set(pred_labels)) - (1 if -1 in pred_labels else 0)}")
print(f"Number of noise points: {list(pred_labels).count(-1)}")
# Out:
# V-Measure Score: 0.0395
# Number of clusters found: 3
# Number of noise points: 0

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import v_measure_score

kmeans = MiniBatchKMeans(n_clusters=3, random_state=42)
pred_labels = kmeans.fit_predict(last_layer)

v_measure = v_measure_score(labels, pred_labels)
print(f"V-Measure Score: {v_measure:.4f}")
print(f"Number of clusters found: {len(set(pred_labels)) - (1 if -1 in pred_labels else 0)}")
print(f"Number of noise points: {list(pred_labels).count(-1)}")
# Out:
# V-Measure Score: 0.1999
# Number of clusters found: 3
# Number of noise points: 0

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import v_measure_score

kmeans = MiniBatchKMeans(n_clusters=3, random_state=42)
pred_labels = kmeans.fit_predict(pooled)

v_measure = v_measure_score(labels, pred_labels)
print(f"V-Measure Score: {v_measure:.4f}")
print(f"Number of clusters found: {len(set(pred_labels)) - (1 if -1 in pred_labels else 0)}")
print(f"Number of noise points: {list(pred_labels).count(-1)}")
# Out:
# V-Measure Score: 0.2084
# Number of clusters found: 3
# Number of noise points: 0
